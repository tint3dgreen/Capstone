# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("../data/interim/housing_data.csv")
data.set_index("OBJECTID", inplace=True)
data.head()
# Out:
#           Unnamed: 0  NEIGH_NO   Neighborhood_Name Neighborhood_Type  \
# OBJECTID
# 1                  0       1.0  Council District 1                CD
# 2                  1       2.0  Council District 2                CD
# 3                  2       3.0  Council District 3                CD
# 4                  3       4.0  Council District 4                CD
# 5                  4       5.0  Council District 5                CD
#
#          Neighborhood_Subtype ACS_Vinatage  Occupied_Housing_Units  \
# OBJECTID
# 1                         NaN         5Y23                   48209
# 2                         NaN         5Y23                   43824
# 3                         NaN         5Y23                   60156
# 4                         NaN         5Y23                   42569
# 5                         NaN         5Y23                   47887
#
#           Owner_Households  Renter_Households  \
# OBJECTID
# 1                    27781              20428
# ...

# %%
data[["Neighborhood_Name","Renter_Households"]]
# Out:
#                 Neighborhood_Name  Renter_Households
# OBJECTID
# 1              Council District 1              20428
# 2              Council District 2              22304
# 3              Council District 3              39514
# 4              Council District 4              23630
# 5              Council District 5              24031
# ...                           ...                ...
# 88            University District               9351
# 89                         Uptown               6894
# 90                       Downtown              22088
# 91        First Hill/Capitol Hill              27914
# 92               Greater Duwamish                175
#
# [92 rows x 2 columns]
