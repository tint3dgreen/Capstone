# %%
import pandas as pd

# %%
income = pd.read_csv('../data/interim/income_data.csv')
income.set_index('OBJECTID', inplace=True)

# %%
income
# Out:
#           Unnamed: 0  NEIGH_NO    Neighborhood_Name Neighborhood_Type  \
# OBJECTID
# 1                  0       1.0   Council District 1                CD
# 2                  1       2.0   Council District 2                CD
# 3                  2       3.0   Council District 3                CD
# 4                  3       4.0   Council District 4                CD
# 5                  4       5.0   Council District 5                CD
# ...              ...       ...                  ...               ...
# 88                87     305.0             Mt Baker              UCUV
# 89                88     312.0     South Lake Union              UCUV
# 90                89     401.0  University District              UCUV
# 91                90     412.0               Uptown              UCUV
# 92                91     413.0             Downtown              UCUV
#
#          Neighborhood_Subtype ACS_Vinatage  \
# OBJECTID
# 1                         NaN         5Y23
# ...
